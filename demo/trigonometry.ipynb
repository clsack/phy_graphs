# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()

N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)

p = figure(title="Basic trigonometry", plot_height=300, plot_width=600, y_range=(-5,5),
           background_fill_color='#efefef')
r = p.line(x, y, color="#8888cc", line_width=1.5, alpha=0.8)

def update(Function, Frequency=1, Amplitude=1, Phase=0, Offset=0):
    if   Function == "sin": func = np.sin
    elif Function == "cos": func = np.cos
    elif Function == "tan": func = np.tan
    r.data_source.data['y'] = Amplitude * func(Frequency * x + Phase) + Offset
    push_notebook()
    
interact(update, Function=["sin", "cos", "tan"], Frequency=(1,50), Amplitude=(0,10), Phase=(0, 20, 0.1), Offset=(0,10))
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3d08ac93-040e-4169-9338-1a2f6f950b64">Loading BokehJS ...</span>
#     </div>
# interactive(children=(Dropdown(description='Function', options=('sin', 'cos', 'tan'), value='sin'), IntSlider(…
#   <div class="bk-root" id="4da74bf2-d51c-43f3-be65-084e8337afe8"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()

N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)

p = figure(title="Basic trigonometry", plot_height=300, plot_width=600, y_range=(-5,5),
           background_fill_color='#efefef')
r = p.line(x, y, color="#8888cc", line_width=1.5, alpha=0.8)

def update(Function, Frequency=1, Amplitude=1, Phase=0, Offset=0):
    if   Function == "sinh": func = np.sinh
    elif Function == "cosh": func = np.cosh
    elif Function == "tanh": func = np.tanh
    r.data_source.data['y'] = Amplitude * func(Frequency * x + Phase) + Offset
    push_notebook()
    
interact(update, Function=["sinh", "cosh", "tanh"], Frequency=(1,50), Amplitude=(0,10), Phase=(0, 20, 0.1), Offset=(0,10))
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f40e8e1e-f809-475a-a6af-f1a06427a6e0">Loading BokehJS ...</span>
#     </div>
# interactive(children=(Dropdown(description='Function', options=('sinh', 'cosh', 'tanh'), value='sinh'), IntSli…
#   <div class="bk-root" id="91ed1cc0-8d31-4894-830d-f49f933dcce1"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>
